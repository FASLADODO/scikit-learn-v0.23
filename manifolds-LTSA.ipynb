# %%
# %matplotlib inline

# %% [markdown]
# ## Local Tangent Space Alignment (LTSA)
# - Algorithmically similar to LLE
# - Tries to model each neighborhood's local geometry via its *tangent space*, then performs a global optimization to learn the embedding.
# - Algorithm structure:
#     - 1) Nearest neighbor search (same as above)
#     - 2) Weight matrix construction - similar to standard LLE
#     - 3) Partial eigenvalue decomposition (same as above)
# - Overall complexity: $O[D \log(k) N \log(N)] + O[D N k^3] + O[k^2 d] + O[d N^2]$

# %%
# LTSA embedding of the digits dataset
print("Computing LTSA embedding")
clf = manifold.LocallyLinearEmbedding(n_neighbors=n_neighbors, n_components=2,
                                      method='ltsa')
t0 = time()
X_ltsa = clf.fit_transform(X)
print("Done. Reconstruction error: %g" % clf.reconstruction_error_)
plot_embedding(X_ltsa,
               "Local Tangent Space Alignment of the digits (time %.2fs)" %
               (time() - t0))
# Out:
# Computing LTSA embedding
# Done. Reconstruction error: 0.212804
